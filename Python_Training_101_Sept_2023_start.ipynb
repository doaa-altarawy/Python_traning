# %% [markdown]
# # Python Training 101 for Data Analysis

# %% [markdown]
# ## Google Colab Shortcuts:
#
# *   Run cell: shift + enter
# *   Autocomplete: ctrl + space
#
#
# ## Topics:
#
#
# *   Import libraries
# *   Defining Variables (int, float, string)
# *   Assignment
# *   Build-in functions: print
# *   pandas DataFrames (~excel table)
# *   read_csv
# *   pandas head and shape
# *   slice data by column
# *   slice data by index
# *   Pandas functions: mean, std, count, max, min
# *   Plotting
# *   Extra topics (time permitting)

# %% [markdown]
# # Part 1: Python Essentials

# %% [markdown]
# ## Import libraries

# %%
# from google.colab import files
# import pandas as pd
# import matplotlib.pyplot as plt

# %%
# This code will allow you to select file from your device an upload it to Google Colab

# %% [markdown]
# ## Defining Variables

# %%
# define a variable by assigning a value to it using `=` sign
# variables start with a letter, case-senstive, and can't be Python reserved keywords

# %%
# Show variable type

# %%
# practice expressions in Python

# %%
# Boolean/bool variables have a value of True or False

# %%
# Use signle or double quotes for variables of type string (or Str in short)

# %% [markdown]
# **Read More about** [Python Data Types here](https://www.w3schools.com/python/python_datatypes.asp).

# %% [markdown]
# ## Print Function

# %%
# Use print fuction to show the value of variables and also add meaningful message

# %%
# Ex: convert KG to LB (There are 2.2 pounds per kilogram), do the math and print a meaningful msg

# %% [markdown]
# # Part 2: Pandas Basics
#
# Read more [here](https://www.geeksforgeeks.org/python-pandas-dataframe/)

# %% [markdown]
# ### Pandas DataFrame - Tables in Python

# %% [markdown]
# ![finallpandas.png](data:image/png;base64,...)

# %% [markdown]
# ![creating_dataframe1.png](data:image/png;base64,...)

# %% [markdown]
# ## Read Pandas DataFrames (Python Tables)

# %%
# Read DataFrame from a csv file, show size (shape), and print sample with the head function

# %%
# You have more options in read_csv funtion
# see docs here: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
# check the data type of each column (not that Strings are shown as object)

# %%
# check all column names in a df

# %% [markdown]
# ### Slice by columns

# %% [markdown]
# ### Slice by Index

# %% [markdown]
# ### Apply fuctions on columns/rows

# %%
# check number of unique customer IDs

# %%
# check the count of each category

# %%
# check the count of each sub-category

# %%
# Find the sum of all sales(use the sum function)

# %%
# What are the max and min sale amounts

# %% [markdown]
# # Part 3: plotting

# %%
# Simple plot of sales

# %%
# convert order date from string (object) to a read date so that we can work with it

# %%
# Set the DataFrame index to be the date

# %%
# If you need to remove/reset the index and make it a regular column (If called multiple times, you will get extra
# unwanted columns, try it)

# %%
# Let's group the data by month then plot again to have a more meaningful plot than the above

# %%
# let's see the sales per year
# see more about the plot function here https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html

# %% [markdown]
# ## Group by function

# %%
# We can group the categorical data like Categories and sub-categories and see the total within each group

# %%
# You can sort values before plotting to look better

# Save previous plot using savefig from matplotlib library (which is used by Pandas under the hood)

# %%
# Let's see total quantity per category

# %% [markdown]
# # Part 4: Extra topics

# %% [markdown]
# ### Queries in DataFrames

# %%
# Run queries on columns and rows as you do in SQL, but different syntax
# let's look at transactions with negative profit due to promotion

# %%
# What are the transactions with negative profit in the Technology category
# Use & (for and), | (for or) to combine conditions, each condition must be between paranthesis

# %% [markdown]
# ### Use Functions and apply in DataFrames

# %%
# We can define functions to do more complex logic
# Let's find flagged transactions with profit worest than -$1000 and the customer purchased high quantity, say greater than 5
# Then let's add a new column called Flagged, which is equal to True if the transaction is flagged, and False if it's not

# %% [markdown]
# # What's Next?
#
#
#
# 1.   **Take this Recommened Course on Udemy**:
#      [Python for Data Science and Machine Learning Bootcamp](https://www.udemy.com/course/python-for-data-science-and-machine-learning-bootcamp/)
#      (until the Capstone project, Skip the Machine Learning lessons)
#
# 2.   **Use Python/Pandas to reimplement your SQL/Excel asks**, you will learn only by applying your knowledge in real problems
